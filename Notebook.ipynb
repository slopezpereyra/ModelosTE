# %%
from generators import gcl, xorshift, SEED, Generator
from simulation import main, poisson_no_homogeneo

# %%
#SEED = 235
generator = Generator(gcl)

#generator.gen_uniform()

# %%
generator.gen_uniform()

# %%
poisson_no_homogeneo(40, generator)
# Out:
# [0.034778149287137156,
#  0.03584457542517369,
#  0.13809189834341984,
#  0.19938987895302931,
#  0.31269499125155054,
#  0.3419050786358991,
#  0.3489344384395172,
#  0.4285533977973326,
#  0.44006915080133674,
#  0.504451436720642,
#  0.5085681344277748,
#  0.5205841901513008,
#  0.5319261106915188,
#  0.5942691714027768,
#  0.600364006336045,
#  0.6378104031525429,
#  0.6516002850939752,
#  0.7202842388314853,
#  0.7560343454396456,
#  0.8020675437555213,
#  0.8100559702733037,
#  0.8711997803786121,
#  0.9288115956581144,
#  0.9332598645139908,
#  0.9724608915433087,
#  1.0739404067147458,
#  1.1812831949342837,
#  1.2423195754338956,
#  1.2781628879241445,
#  1.297226685577764,
#  1.369064072385239,
#  1.387541549669709,
#  1.4310097885342736,
#  1.4391689898984257,
#  1.5518819109812734,
#  1.5566809423569532,
#  1.5612852586911115,
#  1.6357159552384315,
#  1.640626902571799,
#  1.7042722164133393,
#  1.7158036736971727,
#  1.7458860114177805,
#  1.7659864825563487,
# ...

# %%
gcl(11, n=100)

# %%
df = main(generator)
df
# Out:
#       TLlegada       TEspera    TEnSistema   Duracion       TInicio  \
# 0     0.003031      0.000000     42.930562  42.930562      0.003031
# 1     0.072981     42.860612     79.185318  36.324706     42.933593
# 2     0.080709     79.177590    120.604837  41.427247     79.258299
# 3     0.099536    120.586010    133.476764  12.890754    120.685545
# 4     0.136696    133.439604    139.551940   6.112336    133.576300
# ..         ...           ...           ...        ...           ...
# 973  47.885922  32422.424309  32464.309288  41.884979  32470.310231
# 974  47.898013  32464.297197  32470.632626   6.335429  32512.195210
# 975  47.927290  32470.603349  32530.029133  59.425784  32518.530639
# 976  47.943388  32530.013035  32534.507576   4.494541  32577.956423
# 977  47.962652  32534.488312  32555.194339  20.706027  32582.450964
#
#              TFin
# 0       42.933593
# 1       79.258299
# 2      120.685545
# 3      133.576300
# 4      139.688636
# ..            ...
# ...

# %%
x = df["TLlegada"]

# %%
y = df["TLlegada"]

# %%
y

# %%
x == y
